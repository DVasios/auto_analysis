# %%
# App Libs
from src.automate import Automate

# Generic
import pandas as pd

# Warnings
import warnings

# Settings
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)
pd.set_option('display.max_columns', None)

# %%
# Titanic Data | GOOD
tn_filepath = 'data/titanic/titanic.csv'
tn_target = 'Survived'

# Adult | VERY GOOD
at_filepath = 'data/adult/adult.csv'
at_target = 'income'

# Bank Marketing | Kaggle | VERY GOOD
bk_filepath = 'data/bank/bank.csv'
bk_target = 'deposit'

# Raisin | INTER
rs_filepath = 'data/raisin/Raisin_Dataset.csv'
rs_target = 'Class'

# Credit Fraud | Cannot run because it is imbalanced
cc_filepath = 'data/credit_card_fraud/creditcard.csv'
cc_target = 'Class'

# Rain Australia
ra_filepath = 'data/rainAustralia/weatherAUS.csv'
ra_target = 'RainTomorrow'

# Diabetes 
db_filepath = 'data/diabetes/diabetes.csv'
db_target = 'Outcome'

# Heart Disease
hd_filepath = 'data/heart/heart.csv'
hd_target = 'target'

# Ada prior
ad_filepath = 'data/ada_prior/ada_prior.csv'
ad_target = 'label'

# Obesity
ob_filepath = 'data/obesity/obesity.csv'
ob_target = 'NObeyesdad' 

# Mozilla
mo_filepath = 'data/mozilla/mozilla.arff'
mo_target = 'state'

# Page Blocks
pb_filepath = '../../data/sample_data/page_blocks/page_blocks.arff'
pb_target = 'class'

# Page Blocks
pcb_filepath = 'data/pcb/cirrhosis.csv'
pcb_target = 'Status'

# Loan Default
ld_filepath = '../../data/sample_data/loan_default/Loan_default.csv'
ld_target = 'y'

# %%
auto_params = {
    'filepath' : bk_filepath,
    'target' : bk_target,
    'problem_type' : 'classification',
    'model' : 'ensemble',
    'opt_method': 'bayesian',
    'n_iter' : 20
}
automate = Automate(auto_params)
automate.auto_preproc()
# Out:
# Iteration: 20/20

# %%
automate.plot()

# %%
automate.report()
# Out:
# ---- Auto Analysis Report ----
#
# -- Details --
#
# Features: 17
# Rows: 8929
# Missing Data: False
# Duplicates: False
#
# -- Metrics --
#
# Best Accuracy: 0.8097
# Total Running Time: 1 minutes and 29 seconds
#
# -- Suggested Pipeline --
#
# Outlier IQR Threshold: none
# Imputation Type: Median
# Encoding Type: One-hot
# Scale Type: None
# Selection Type: Variance_Thres
# Selection Percentage: 75.0 %

# %%
automate.hp_optization(100)
# Out:
# Best XGBoost Accuracy: 0.8195
# Best Parameters: {'subsample': 1.0, 'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.1, 'colsample_bytree': 1.0}

# %%
automate.save('results/results.csv')

# %%
res = pd.read_csv('results/results.csv')

# %%
res
# Out:
#               Dataset  Features  Rows  MissingData  Duplicates  BestAccuracy  \
# 0  data/bank/bank.csv        17  8929        False       False        0.8097
#
#                 TimeRunning Iteration OutlierThres ImputationType  \
# 0  1 minutes and 29 seconds      none       Median        One-Hot
#
#    EncodingType       ScaleType  SelectionType  SelectionPercentage
# 0           NaN  Variance_Thres           0.75                  NaN
