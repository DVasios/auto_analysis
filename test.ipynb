# %%
# App Libs
from src.automate import Automate

# Generic
import pandas as pd

# Warnings
import warnings
from sklearn.exceptions import ConvergenceWarning

# Settings
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)
warnings.filterwarnings('ignore', category=ConvergenceWarning)

# %%
# ---- Experiment Datasets ----

# Ada prior
ad_filepath = 'data/ada_prior/data.csv'
ad_target = 'label'

# eeg
ee_filepath = 'data/eeg/data.csv'
ee_target = 'Class'

# us census
ce_filepath = 'data/uscensus/data.csv'
ce_target = 'Income'

# House Prices
hp_filepath = 'data/houses/data.csv'
hp_target = 'SalePrice>150k'

# Obesity
ob_filepath = 'data/obesity/data.csv'
ob_target = 'NObeyesdad' 

# Avila Dataset
av_filepath = 'data/avila/data.csv'
av_target = 'Class'

# PBCSeq
pb_filepath = 'data/pbcseq/data.csv'
pb_target = 'binaryClass'

# Mozilla
mo_filepath = 'data/mozilla/data.csv'
mo_target = 'state'

# Page blocks
pbl_filepath = 'data/page_blocks/data.csv'
pbl_target = 'class'

# Wall robot nav
wr_filepath = 'data/wall-robot-nav/data.csv'
wr_target = 'Class'


# ----
imdb_filepath = 'data/imdb.csv'
imdb_target = 'sentiment'

# %%
auto_params = {
    'filepath'  : ad_filepath,
    'target' : ad_target,
    'problem_type' : 'classification',
    'model' : 'lg',
    'opt_method': 'random',
    'cv' : 5,
    'n_iter' : 1,
    'evaluation_type' : 'basic'
}
automate = Automate(auto_params)
# automate.auto_analysis()

# %%
# automate.plot()

# %%
# automate.report()

# %%
automate.evaluate('lg', 50)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END .............................................C=0.01; total time=   0.1s
# [CV] END .............................................C=0.01; total time=   0.1s
# [CV] END .............................................C=0.01; total time=   0.1s
# [CV] END .............................................C=0.01; total time=   0.1s
# [CV] END .............................................C=0.01; total time=   0.1s
# [CV] END .............................................C=0.05; total time=   0.1s
# [CV] END .............................................C=0.05; total time=   0.1s
# [CV] END .............................................C=0.05; total time=   0.1s
# [CV] END .............................................C=0.05; total time=   0.1s
# [CV] END .............................................C=0.05; total time=   0.1s
# [CV] END ..............................................C=0.1; total time=   0.1s
# ...

# %%
automate.evaluate('xgb', 50)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits

# %%
automate.save('results/results.csv')

# %%
res = pd.read_csv('results/results.csv')

# %%
res
